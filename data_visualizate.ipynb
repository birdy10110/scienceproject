# %% [markdown]
# <a href="https://colab.research.google.com/github/birdy10110/scienceproject/blob/main/data_visualizate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geopandas

# %%
import geopandas as gpd

# %%
# !wget https://github.com/iamtekson/geospatial-data-analysis-python/tree/master/data/shp
# Out:
# --2024-12-11 21:10:49--  https://github.com/iamtekson/geospatial-data-analysis-python/tree/master/data/shp
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘shp’
#
# shp                     [ <=>                ] 285.66K  --.-KB/s    in 0.1s
#
# 2024-12-11 21:10:50 (2.21 MB/s) - ‘shp’ saved [292516]

# %%
# !git clone https://github.com/iamtekson/geospatial-data-analysis-python/tree/master/data/shp
# Out:
# fatal: destination path 'shp' already exists and is not an empty directory.

# %%
# !git clone https://github.com/iamtekson/geospatial-data-analysis-python.git
# Out:
# Cloning into 'geospatial-data-analysis-python'...
# remote: Enumerating objects: 145, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 145 (delta 18), reused 25 (delta 7), pack-reused 89 (from 1)
# Receiving objects: 100% (145/145), 48.21 MiB | 34.21 MiB/s, done.
# Resolving deltas: 100% (38/38), done.

# %%
# !ls /content/geospatial-data-analysis-python/data/shp
# Out:
# municipality.dbf   municipality.sbx	 nepal_district  pokhara.sbn	  pokhara.shx
# municipality.json  municipality.shp	 pokhara.cpg	 pokhara.sbx
# municipality.prj   municipality.shp.xml  pokhara.dbf	 pokhara.shp
# municipality.sbn   municipality.shx	 pokhara.prj	 pokhara.shp.xml

# %%
in_geojson = r'/content/geospatial-data-analysis-python/data/shp/municipality.json'
in_shp = r'/content/geospatial-data-analysis-python/data/shp/municipality.shp'

# %%
gdf = gpd.read_file(in_geojson)
gdf.head()
# Out:
#    OBJECTID   DISTRICT        GaPa_NaPa     Type_GN Province  SCode  DCode  \
# 0         1  TAPLEJUNG  Aathrai Tribeni  Gaunpalika        1      1      1
# 1         2  TAPLEJUNG       Maiwakhola  Gaunpalika        1      1      1
# 2         3  TAPLEJUNG        Meringden  Gaunpalika        1      1      1
# 3         4  TAPLEJUNG       Mikwakhola  Gaunpalika        1      1      1
# 4         5  TAPLEJUNG     Phaktanglung  Gaunpalika        1      1      1
#
#    SDD  MCode      length         area  SDDMM          Nepali  Shape_Leng  \
# 0  101      1   44.672747    88.825948  10101  आठराई त्रिवेणी    0.430900
# 1  101      2   61.067429   137.848122  10102        मैवाखोला    0.577692
# 2  101      3   75.987469   210.313039  10103        मेरिङदेन    0.718499
# 3  101      4  123.175400   442.960328  10104      मिक्वाखोला    1.164097
# 4  101      5  228.107830  1858.441119  10105       फक्ताङलुङ    2.186142
#
#    Shape_Area                                           geometry
# ...

# %%
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gdf.geom_type
# Out:
# 0      Polygon
# 1      Polygon
# 2      Polygon
# 3      Polygon
# 4      Polygon
#         ...
# 769    Polygon
# 770    Polygon
# 771    Polygon
# 772    Polygon
# 773    Polygon
# Length: 774, dtype: object

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
gdf.plot('DISTRICT')
# Out:
# <Axes: >

# %%
gdf.head()
# Out:
#    OBJECTID   DISTRICT        GaPa_NaPa     Type_GN Province  SCode  DCode  \
# 0         1  TAPLEJUNG  Aathrai Tribeni  Gaunpalika        1      1      1
# 1         2  TAPLEJUNG       Maiwakhola  Gaunpalika        1      1      1
# 2         3  TAPLEJUNG        Meringden  Gaunpalika        1      1      1
# 3         4  TAPLEJUNG       Mikwakhola  Gaunpalika        1      1      1
# 4         5  TAPLEJUNG     Phaktanglung  Gaunpalika        1      1      1
#
#    SDD  MCode      length         area  SDDMM          Nepali  Shape_Leng  \
# 0  101      1   44.672747    88.825948  10101  आठराई त्रिवेणी    0.430900
# 1  101      2   61.067429   137.848122  10102        मैवाखोला    0.577692
# 2  101      3   75.987469   210.313039  10103        मेरिङदेन    0.718499
# 3  101      4  123.175400   442.960328  10104      मिक्वाखोला    1.164097
# 4  101      5  228.107830  1858.441119  10105       फक्ताङलुङ    2.186142
#
#    Shape_Area                                           geometry
# ...

# %%
gdf.plot('Province', legend=True)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
fig, ax= plt.subplots(1, figsize=(4.5,10))
gdf.plot(ax=ax, column='Province', legend=True, legend_kwds={'loc': 'center left'})
leg = ax.get_legend()
leg.set_bbox_to_anchor((1.04, 0.5))
